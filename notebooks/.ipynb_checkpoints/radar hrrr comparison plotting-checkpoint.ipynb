# %%
radar_directory = '/home/mjohnson/python/radar_txt'
hrrr_directory = '/home/mjohnson/python/hrrr_txt'

# %%
import datetime
import pyhrrr
import json
import os
import matplotlib.dates
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
date = datetime.datetime(2014,7,1) #change for date

# %%
radar_string = pyhrrr.produce_radar_txt_string(date)
hrrr_string = pyhrrr.produce_hrrr_txt_string(date,filenum = 24,hour = 1,loc=[36.605, -97.485], indexes = None,
 modelhours = False)

# %%
wkdir = os.getcwd()
os.chdir(hrrr_directory)
#hrrrf = open(hrrr_string,'r')
#hrrr = json.load(hrrrf)
os.chdir(radar_directory)
radarf = open(radar_string,'r')
radar = json.load(radarf)

# %%
hrrr[0] = np.array(hrrr[0])
heights = radar[2]
snr = np.array(radar[1])
#ind = hrrr[2].index() #change for parameter
hrrr_data = np.array(hrrr[0][:,-5,:])+np.array(hrrr[0][:,-4,:])+np.array(hrrr[0][:,-3,:])+np.array(hrrr[0][:,-2,:])+np.array(hrrr[0][:,-1,:])
press_index = pyhrrr.HRRR_PS.tolist().index(800)
#hrrr_c = hrrr_data[:,ind]
radar_data = np.array(radar[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-30849a3cd936> in <module>()
# ----> 1 hrrr[0] = np.array(hrrr[0])
#       2 heights = radar[2]
#       3 snr = np.array(radar[1])
#       4 #ind = hrrr[2].index() #change for parameter
#       5 hrrr_data = np.array(hrrr[0][:,-5,:])+np.array(hrrr[0][:,-4,:])+np.array(hrrr[0][:,-3,:])+np.array(hrrr[0][:,-2,:])+np.array(hrrr[0][:,-1,:])
#
# NameError: name 'hrrr' is not defined

# %%
radar_m = pyhrrr.filter_mask(radar_data,snr,-14)
radar_i = pyhrrr.filter_mask(radar_data,snr,-14)

ceil_pres = np.interp(radar[2],radar[3],np.array(pyhrrr.HRRR_PS))

#import bisect
#ceil_inds = []
#for i in ceil_pres:
 #ceil_inds.append(bisect.bisect_left(pyhrrr.HRRR_PS.tolist(),i))

for k in range(radar_data.shape[0]):
     if radar[2][k] == 2000.:
         radar_m[k,:] = np.ma.masked_where(radar_m[k,:]!=-5000,radar_m[k,:])
     else:
         boolean = np.multiply(ceil_pres[k]<pyhrrr.HRRR_PS[2:40],radar_m[k,:]<-15)
         radar_m[k,:] = np.ma.masked_where(boolean,radar_data[k,:]) 

 
radar_m = np.ma.masked_where(radar_m==-np.inf,radar_m)


radar_i = np.ma.masked_where(radar_i==-np.inf,radar_i)


hrrr_data_m = pyhrrr.filter_mask(hrrr_data,hrrr_data,10**-5)
rh_m = pyhrrr.filter_mask(hrrr[0][:,2,:],hrrr[0][:,2,:],80)

# %%
matplotlib.dates.num2date(hrrr[1])
# Out:
# [datetime.datetime(2014, 6, 1, 23, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 0, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 1, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 2, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 3, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 4, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 5, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 6, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 7, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 8, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 9, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 10, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 11, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 12, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 13, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 14, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 15, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 16, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 17, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 18, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>),
#  datetime.datetime(2014, 6, 2, 19, 0, tzinfo=<matplotlib.dates._UTC object at 0x2ae075b161d0>)]

# %%
plt.plot(ceil_pres)

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr_data_m,final_unit = 'Total mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(radar_m,final_unit = 'dBz',date = None,loc = None,ps = pyhrrr.HRRR_PS[1:40], hour=1, scaling = 1,
 figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr_data,final_unit = 'Total mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(radar_i,final_unit = 'dBz',date = None,loc = None,ps = pyhrrr.HRRR_PS[1:40], hour=1, scaling = 1,
 figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(rh_m,final_unit = pyhrrr.HRRR_VARS[2]+' %',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,2,:],final_unit = pyhrrr.HRRR_VARS[2]+' %',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(snr,final_unit = 'snr dB',date = None,loc = None,ps = pyhrrr.HRRR_PS[1:40], hour=1, scaling = 1,
 figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-5,:],final_unit = 'Cloud mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-4,:],final_unit = pyhrrr.HRRR_VARS[-4]+' kg/kg**-1',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-3,:],final_unit = pyhrrr.HRRR_VARS[-3]+' kg/kg**-1',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-2,:],final_unit = pyhrrr.HRRR_VARS[-2]+' kg/kg**-1',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-1,:],final_unit = pyhrrr.HRRR_VARS[-1]+' kg/kg**-1',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,6,:],final_unit = pyhrrr.HRRR_VARS[6]+' m/s',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,7,:],final_unit = pyhrrr.HRRR_VARS[7]+' m/s',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,5,:],final_unit = pyhrrr.HRRR_VARS[5]+' m/s',numdates = hrrr[1],date = None,
 loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
filename = pyhrrr.produce_hrrr_grib2strings(date+datetime.timedelta(hours=10),1)
filename = filename[0]

# %%
filename in os.listdir('/data/san_store/HRRR')
# Out:
# True

# %%
pyhrrr.plot_hrrr_sgp(filename,parameter='Total mixing ratio',directory = '/data/san_store/HRRR',hinp = '', scaling = 1, final_unit = '', margin = .3)

# %%
filename = pyhrrr.produce_hrrr_grib2strings(date+datetime.timedelta(hours=5),1)
filename = filename[0]

# %%
filename in os.listdir('/data/san_store/HRRR')
# Out:
# True

# %%
pyhrrr.plot_hrrr_sgp(filename,parameter='Total mixing ratio',directory = '/data/san_store/HRRR',hinp = '', scaling = 1, final_unit = '', margin = .3)

# %%
filename = pyhrrr.produce_hrrr_grib2strings(date+datetime.timedelta(hours=9),1)
filename = filename[0]

# %%
filename in os.listdir('/data/san_store/HRRR')
# Out:
# True

# %%
pyhrrr.plot_hrrr_sgp(filename,parameter='Total mixing ratio',directory = '/data/san_store/HRRR',hinp = '', scaling = 1, final_unit = '', margin = .3)

# %%
filename = pyhrrr.produce_hrrr_grib2strings(date+datetime.timedelta(hours=16),1)
filename = filename[0]

# %%
filename in os.listdir('/data/san_store/HRRR')
# Out:
# True

# %%
pyhrrr.plot_hrrr_sgp(filename,parameter='Total mixing ratio',directory = '/data/san_store/HRRR',hinp = '', scaling = 1, final_unit = '', margin = .3)

# %%
filename = pyhrrr.produce_hrrr_grib2strings(date+datetime.timedelta(hours=17),1)
filename = filename[0]
filename in os.listdir('/data/san_store/HRRR')
# Out:
# True

# %%
pyhrrr.plot_hrrr_sgp(filename,parameter='Total mixing ratio',directory = '/data/san_store/HRRR',hinp = '', scaling = 1, final_unit = '', margin = .3)

# %%
pyhrrr.HRRR_PS
# Out:
# array([1013, 1000,  975,  950,  925,  900,  875,  850,  825,  800,  775,
#         750,  725,  700,  675,  650,  625,  600,  575,  550,  525,  500,
#         475,  450,  425,  400,  375,  350,  325,  300,  275,  250,  225,
#         200,  175,  150,  125,  100,   75,   50])
