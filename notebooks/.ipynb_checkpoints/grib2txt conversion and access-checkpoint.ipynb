# %%
import pyhrrr
import numpy as np

# %%
directory = '/Users/mattjohnson/HRRRs'
import datetime
name = pyhrrr.produce_hrrr_txt_string(date = datetime.datetime(2014,5,29,11),filenum = 5,hour = 1)

# %%
pyhrrr.write_hrrr_grib2txt(date = datetime.datetime(2014,5,29,11),filenum = 5,hour = 1,directory = directory,enddirectory = directory)
# Out:
# [['hrrr.3d.201405291000f001.grib2'], ['hrrr.3d.201405291100f001.grib2'], ['hrrr.3d.201405291200f001.grib2'], ['hrrr.3d.201405291300f001.grib2'], ['hrrr.3d.201405291400f001.grib2']]
# [datetime.datetime(2014, 5, 29, 10, 0), datetime.datetime(2014, 5, 29, 11, 0), datetime.datetime(2014, 5, 29, 12, 0), datetime.datetime(2014, 5, 29, 13, 0), datetime.datetime(2014, 5, 29, 14, 0)]
# 160.678497
# 'hrrr.3d.20140529t011016r001L459899.txt'

# %%
x = pyhrrr.read_hrrr_txt(filename = name,directory='/Users/mattjohnson/HRRRs')
# Out:
# /Users/mattjohnson/HRRRs

# %%
x
# Out:
# [[[-2.37200927734375,
#    111.60568237304688,
#    330.1834716796875,
#    555.031005859375,
#    786.543701171875,
#    1023.531005859375,
#    1265.869873046875,
#    1513.83203125,
#    1767.70458984375,
#    2027.924560546875,
#    2294.82666015625,
#    2568.951171875,
#    2849.42578125,
#    3137.85791015625,
#    3435.103515625,
#    3740.2744140625,
#    4056.40185546875,
#    4382.53515625,
#    4721.04296875,
#    5072.03125,
#    5436.55078125,
#    5816.37890625,
#    6210.69140625,
#    6623.34765625,
#    7054.37109375,
#    7504.59375,
#    7977.55859375,
#    8475.6953125,
#    9002.515625,
#    9562.5,
#    10160.265625,
#    10799.15625,
#    11490.83984375,
#    12251.34765625,
#    13104.99609375,
#    14074.97265625,
#    15201.2734375,
#    16554.28125,
#    18278.74609375,
#    20732.7890625],
#   [294.80029296875,
#    294.072998046875,
#    291.177490234375,
#    294.638427734375,
#    294.259765625,
#    293.010986328125,
#    291.447021484375,
# ...

# %%
name = pyhrrr.produce_hrrr_txt_string(date = datetime.datetime(2014,5,29,12),filenum = 4,hour = [1,4],modelhours=True)

# %%
name
# Out:
# 'hrrr.3d.20140529t012m001004L459899.txt'

# %%
pyhrrr.write_hrrr_grib2txt(date = datetime.datetime(2014,5,29,12),filenum = 4,hour = [1,4],directory = directory,enddirectory = directory,write_modelhours=True)
# Out:
# [['hrrr.3d.201405291100f001.grib2', 'hrrr.3d.201405291100f002.grib2', 'hrrr.3d.201405291100f003.grib2', 'hrrr.3d.201405291100f004.grib2']]
# [datetime.datetime(2014, 5, 29, 11, 0)]
# 32.523989
# 'hrrr.3d.20140529t012m001004L459899.txt'

# %%
y = pyhrrr.read_hrrr_txt(filename = name, directory='/Users/mattjohnson/HRRRs')
# Out:
# /Users/mattjohnson/HRRRs

# %%
y
# Out:
# [[[-2.9461669921875,
#    111.2015380859375,
#    330.0671691894531,
#    555.260009765625,
#    787.159912109375,
#    1024.4189453125,
#    1266.89501953125,
#    1514.80078125,
#    1768.600830078125,
#    2028.64453125,
#    2295.4375,
#    2569.451416015625,
#    2849.8134765625,
#    3138.021240234375,
#    3435.005859375,
#    3740.0751953125,
#    4056.212158203125,
#    4382.5625,
#    4721.2734375,
#    5072.359375,
#    5436.890625,
#    5816.54296875,
#    6210.44140625,
#    6622.52734375,
#    7052.8828125,
#    7502.54296875,
#    7974.98046875,
#    8472.609375,
#    8998.84765625,
#    9558.03515625,
#    10154.9296875,
#    10793.05078125,
#    11484.4921875,
#    12245.515625,
#    13098.859375,
#    14069.4609375,
#    15197.625,
#    16552.33984375,
#    18279.63671875,
#    20737.96484375],
#   [295.22412109375,
#    294.51220703125,
#    291.303466796875,
#    295.123046875,
#    294.748046875,
#    293.175537109375,
#    291.37353515625,
#    289.80517578125,
# ...
