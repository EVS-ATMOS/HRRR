# %%
enddirectory = '/home/mjohnson/python/hrrr_txt'

# %%
directory = '/data/san_store/HRRR'

# %%
import datetime

# %%
startdate = datetime.datetime(2014,3,15)

# %%
enddate = datetime.datetime(2014,4,1)

# %%
import pyhrrr

# %%
pyhrrr.massconvert_hrrr_grib2txt(startdate=startdate,enddate=enddate,hours = [1,2,3,4],directory=directory,enddirectory=enddirectory)
# Out:
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 00:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 01:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# requested datetime not in path:
# 2014-03-15 02:00:00
# (no files gathered for this date)
#
# requested datetime not in path:
# 2014-03-15 03:00:00
# (no files gathered for this date)
#
# requested datetime not in path:
# 2014-03-15 04:00:00
# (no files gathered for this date)
#
# requested datetime not in path:
# 2014-03-15 05:00:00
# (no files gathered for this date)
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 06:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# requested datetime not in path:
# 2014-03-15 07:00:00
# (no files gathered for this date)
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 08:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# requested datetime not in path:
# 2014-03-15 09:00:00
# (no files gathered for this date)
#
# requested datetime not in path:
# 2014-03-15 10:00:00
# (no files gathered for this date)
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 11:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 12:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# requested datetime not in path:
# 2014-03-15 13:00:00
# (no files gathered for this date)
#
# requested datetime not in path:
# 2014-03-15 14:00:00
# (no files gathered for this date)
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 15:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 16:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 17:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 18:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 19:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 20:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 21:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 22:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
#
# at least one requested model hour not in path for:
# date requested:
# 2014-03-15 23:00:00
# (no files gathered for this date)
# hours requested:
# [0]
# hours present:
# [1, 2, 3, 4]
# []
# [datetime.datetime(2014, 3, 15, 0, 0), datetime.datetime(2014, 3, 15, 1, 0), datetime.datetime(2014, 3, 15, 2, 0), datetime.datetime(2014, 3, 15, 3, 0), datetime.datetime(2014, 3, 15, 4, 0), datetime.datetime(2014, 3, 15, 5, 0), datetime.datetime(2014, 3, 15, 6, 0), datetime.datetime(2014, 3, 15, 7, 0), datetime.datetime(2014, 3, 15, 8, 0), datetime.datetime(2014, 3, 15, 9, 0), datetime.datetime(2014, 3, 15, 10, 0), datetime.datetime(2014, 3, 15, 11, 0), datetime.datetime(2014, 3, 15, 12, 0), datetime.datetime(2014, 3, 15, 13, 0), datetime.datetime(2014, 3, 15, 14, 0), datetime.datetime(2014, 3, 15, 15, 0), datetime.datetime(2014, 3, 15, 16, 0), datetime.datetime(2014, 3, 15, 17, 0), datetime.datetime(2014, 3, 15, 18, 0), datetime.datetime(2014, 3, 15, 19, 0), datetime.datetime(2014, 3, 15, 20, 0), datetime.datetime(2014, 3, 15, 21, 0), datetime.datetime(2014, 3, 15, 22, 0), datetime.datetime(2014, 3, 15, 23, 0)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-f47d68e42ceb> in <module>()
# ----> 1 pyhrrr.massconvert_hrrr_grib2txt(startdate=startdate,enddate=enddate,directory=directory,enddirectory=enddirectory)
#
# /home/mjohnson/python/HRRR/notebooks/pyhrrr.pyc in massconvert_hrrr_grib2txt(startdate, enddate, modelstartindex, directory, enddirectory, loc, indexes, modelhours)
#      38         for i in datestrings:
#      39             for j in range(len(filelists[0])):
# ---> 40                 write_hrrr_grib2txt(i,hour = j,directory=directory,enddirectory=enddirectory,loc=loc, indexes = indexes,write_modelhours = modelhours)
#      41
#      42     else:
#
# /home/mjohnson/python/HRRR/notebooks/pyhrrr.pyc in write_hrrr_grib2txt(date, filenum, hour, directory, enddirectory, loc, indexes, write_modelhours)
#      51     print filelists
#      52     print datestrings
# ---> 53     [data,parameterlist,datah,loc,indexes,units] = read_hrrr_spec(filename = filelists[0][0], directory = directory)
#      54     data = np.array(data)
#      55     data = data.tolist()
#
# IndexError: list index out of range
