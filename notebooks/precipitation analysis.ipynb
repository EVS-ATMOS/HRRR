# %%
import pyhrrr
import datetime
# %matplotlib inline

# %%
date = datetime.datetime(2014,4,14) #change for date
pyhrrr.plot_disdrometer(date,'/data/san_store/gmckercher/disdrometer/mckercherg1/160313')
# Out:
# --------------------------------------------------------------
# -----------------PRECIPITATION INFORMATION--------------------
# --------------------------------------------------------------
#
# Total Precipitation Duration: 2.83333333333 hours, 170.0 minutes, 10200.0 seconds
# Total Precipitation Amount: 0.0453 mm, 0.000178346668032 in
# Total Rain Rate Recording Duration: 13.0666666667 hours, 784.0 minutes, 47040.0 seconds
# Light Rain Rate Duration:
#  13.0666666667 hours, 784.0 minutes, 47040.0 seconds
# Medium Rain Rate Duration: 0.0 hours, 0.0 minutes, 0.0 seconds
# Heavy Rain Rate Duration: 0.0 hours, 0.0 minutes, 0.0 seconds
# Average Rain Rate: 0.00207294 mm/hr, 8.16120154487e-06 in/hr
