# %%
import pyhrrr
import datetime
import json
import os
import matplotlib.dates
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
# %matplotlib inline

# %%
date = datetime.datetime(2014,7,28) #change for date

# %%
pyhrrr.plot_kazr((date),
                      '/data/san_store/radar/sgp/kazr/mckercherg1/160107')

# %%
pyhrrr.plot_disdrometer(date,'/data/san_store/gmckercher/disdrometer/mckercherg1/160313')
# Out:
# --------------------------------------------------------------
# -----------------PRECIPITATION INFORMATION--------------------
# --------------------------------------------------------------
#
# Total Precipitation Duration: 0.0333333333333 hours, 2.0 minutes, 120.0 seconds
# Total Precipitation Amount: 0.0873 mm, 0.000343700983137 in
# Total Rain Rate Recording Duration: 2.23333333333 hours, 134.0 minutes, 8040.0 seconds
# Light Rain Rate Duration: 2.21666666667 hours, 133.0 minutes, 7980.0 seconds
# Medium Rain Rate Duration: 0.0166666666667 hours, 1.0 minutes, 60.0 seconds
# Heavy Rain Rate Duration:
#  0.0 hours, 0.0 minutes, 0.0 seconds
# Average Rain Rate: 0.00367944 mm/hr, 1.44859797292e-05 in/hr

# %%
radar_directory = '/data/san_store/radar_txt'
hrrr_directory = '/data/san_store/hrrr_txt'
radar_string = pyhrrr.produce_radar_txt_string(date)
hrrr_string = pyhrrr.produce_hrrr_txt_string(date,filenum = 24,hour = 1,loc=[36.605, -97.485], indexes = None,
                                             modelhours = False)
wkdir = os.getcwd()
os.chdir(hrrr_directory)
hrrrf = open(hrrr_string,'r')
hrrr = json.load(hrrrf)
os.chdir(radar_directory)
radarf = open(radar_string,'r')
radar = json.load(radarf)

hrrr[0] = np.array(hrrr[0])
heights = radar[2]
snr = np.array(radar[1])
#ind = hrrr[2].index() #change for parameter
hrrr_data = np.array(hrrr[0][:,-5,:])+np.array(hrrr[0][:,-4,:])+np.array(hrrr[0][:,-3,:])+np.array(hrrr[0][:,-2,:])+np.array(hrrr[0][:,-1,:])
press_index = pyhrrr.HRRR_PS.tolist().index(800)
#hrrr_c = hrrr_data[:,ind]
radar_data = np.array(radar[0])


radar_m = pyhrrr.filter_mask(radar_data,snr,-14)
radar_i = pyhrrr.filter_mask(radar_data,snr,-14)

ceil_pres = np.interp(radar[2],radar[3],np.array(pyhrrr.HRRR_PS))

#import bisect
#ceil_inds = []
#for i in ceil_pres:
    #ceil_inds.append(bisect.bisect_left(pyhrrr.HRRR_PS.tolist(),i))

for k in range(radar_data.shape[0]):
    if radar[2][k] == 2000.:
        radar_m[k,:] = np.ma.masked_where(radar_m[k,:]!=-5000,radar_m[k,:])
    #else:
        #pass
        #c_ind = ceil_inds[k]
        #temp = radar_m[k,0:c_ind+1]
        #temp2 = radar_m[k,c_ind+1::]
        #radar_m[k,0:c_ind+1,] = np.ma.masked_where(temp<-5000,temp)
        #radar_m[k,c_ind+1::] = np.ma.array(temp2)

    
radar_m = np.ma.masked_where(radar_m==-np.inf,radar_m)


radar_i = np.ma.masked_where(radar_i==-np.inf,radar_i)


hrrr_data_m = pyhrrr.filter_mask(hrrr_data,hrrr_data,10**-5)
rh_m = pyhrrr.filter_mask(hrrr[0][:,2,:],hrrr[0][:,2,:],80)

# %%
fig = plt.figure(figsize = [12,6])

plt.title( 'Ceilometer First Cloud Base Height' )
plt.xlabel('UTC Time (Hour)',fontsize=14)
plt.ylabel('Pressure (hPa)',fontsize=14)

ax1 = plt.gca()
ax1.set_yscale('log')
ax1.set_ylim([1000,100])
ax1.set_xlim([0,24])
# x axis
xmajorLocator = MultipleLocator(1)
ax1.xaxis.set_major_locator(xmajorLocator)
xmajorFormatter = FormatStrFormatter('%d')
ax1.xaxis.set_major_formatter(xmajorFormatter)
# y axis
ymajorLocator = MultipleLocator(100)
ax1.yaxis.set_major_locator(ymajorLocator)
ymajorFormatter = FormatStrFormatter('%d')
ax1.yaxis.set_major_formatter(ymajorFormatter)

plt.plot(ceil_pres,c='g',lw=4)

# %%
pyhrrr.plot_hrrr_dayfromtxt(radar_m,final_unit = 'dBz',ps = pyhrrr.HRRR_PS[1:40], hour=1, scaling = 1,
                            figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr_data_m,final_unit = 'Total mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-5d6d015f9c1d> in <module>()
#       1 pyhrrr.plot_hrrr_dayfromtxt(hrrr_data_m,final_unit = 'Total mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
# ----> 2                             loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])
#
# /data/san_store/radar_txt/pyhrrr.pyc in plot_hrrr_dayfromtxt(matrix, final_unit, numdates, date, loc, ps, hour, scaling, figsize, log, invert, ylabel)
#      67         ax.invert_yaxis()
#      68
# ---> 69     plt.colorbar(mappable = pc,label=final_unit)
#      70     plt.xlabel('Time in hrs')
#      71     plt.ylabel(ylabel)
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in colorbar(mappable, cax, ax, **kw)
#    2152         ax = gca()
#    2153
# -> 2154     ret = gcf().colorbar(mappable, cax = cax, ax=ax, **kw)
#    2155     draw_if_interactive()
#    2156     return ret
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    1498                 cax, kw = cbar.make_axes(ax, **kw)
#    1499         cax.hold(True)
# -> 1500         cb = cbar.colorbar_factory(cax, mappable, **kw)
#    1501
#    1502         self.sca(current_ax)
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in colorbar_factory(cax, mappable, **kwargs)
#    1314         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1315     else:
# -> 1316         cb = Colorbar(cax, mappable, **kwargs)
#    1317
#    1318     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in __init__(self, ax, mappable, **kw)
#     890                 kw['alpha'] = mappable.get_alpha()
#     891
# --> 892             ColorbarBase.__init__(self, ax, **kw)
#     893
#     894     def on_mappable_changed(self, mappable):
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in __init__(self, ax, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     319         # The rest is in a method so we can recalculate when clim changes.
#     320         self.config_axis()
# --> 321         self.draw_all()
#     322
#     323     def _extend_lower(self):
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in draw_all(self)
#     340         and do all the drawing.
#     341         '''
# --> 342         self._process_values()
#     343         self._find_range()
#     344         X, Y = self._mesh()
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.pyc in _process_values(self, b)
#     656             self.norm.vmin, self.norm.vmax = mtrans.nonsingular(self.norm.vmin,
#     657                                                                 self.norm.vmax,
# --> 658                                                                 expander=0.1)
#     659             if not self.norm.scaled():
#     660                 self.norm.vmin = 0
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in nonsingular(vmin, vmax, expander, tiny, increasing)
#    2640     returns -*expander*, *expander*.
#    2641     '''
# -> 2642     if (not np.isfinite(vmin)) or (not np.isfinite(vmax)):
#    2643         return -expander, expander
#    2644     swapped = False
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
pyhrrr.plot_hrrr_dayfromtxt(rh_m,final_unit =  pyhrrr.HRRR_VARS[2]+' %',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,5,:],final_unit =  pyhrrr.HRRR_VARS[5]+' m/s',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
import pyhrrr
import datetime
# %matplotlib inline
pyhrrr.plot_skewt_compare(date,'/data/san_store/soundings/sgp/mckercherg1/159821',1,sound_num=1)
pyhrrr.plot_skewt_compare(date,'/data/san_store/soundings/sgp/mckercherg1/159821',1,sound_num=2)
pyhrrr.plot_skewt_compare(date,'/data/san_store/soundings/sgp/mckercherg1/159821',1,sound_num=3)
pyhrrr.plot_skewt_compare(date,'/data/san_store/soundings/sgp/mckercherg1/159821',1,sound_num=4)
# Out:
# Reading sgpsondewnpnC1.b1.20140728.052600.cdf
# No cloud
# Reading hrrr.3d.20140728t000024r001L459899.txt
# HRRR Model Sounding, Forecast: 2014-07-28 04:26:00 for 1 hour
# Reading sgpsondewnpnC1.b1.20140728.112600.cdf
# No cloud
# Reading hrrr.3d.20140728t000024r001L459899.txt
# HRRR Model Sounding, Forecast: 2014-07-28 10:26:00 for 1 hour
# Reading sgpsondewnpnC1.b1.20140728.173100.cdf
# No cloud
# Reading hrrr.3d.20140728t000024r001L459899.txt
# HRRR Model Sounding, Forecast: 2014-07-28 16:31:00 for 1 hour
# Reading sgpsondewnpnC1.b1.20140728.233200.cdf
# No cloud
# Reading hrrr.3d.20140728t000024r001L459899.txt
# HRRR Model Sounding, Forecast: 2014-07-28 22:32:00 for 1 hour

# %%
# Uncomment to see the different mixing ratios
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-5,:],final_unit = 'Cloud mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-4,:],final_unit =  pyhrrr.HRRR_VARS[-4]+' kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-3,:],final_unit =  pyhrrr.HRRR_VARS[-3]+' kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-2,:],final_unit =  pyhrrr.HRRR_VARS[-2]+' kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-1,:],final_unit =  pyhrrr.HRRR_VARS[-1]+' kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
filename = pyhrrr.produce_hrrr_grib2strings([date+datetime.timedelta(hours=12)],[[1]])
filename = filename[0]
pyhrrr.plot_hrrr_sgp(filename,parameter='Total mixing ratio',directory = '/data/san_store/HRRR',hinp = '', scaling = 1, final_unit = '', margin = .3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-c597441b9003> in <module>()
#       1 filename = pyhrrr.produce_hrrr_grib2strings([date+datetime.timedelta(hours=12)],[[1]])
#       2 filename = filename[0]
# ----> 3 pyhrrr.plot_hrrr_sgp(filename,parameter='Total mixing ratio',directory = '/data/san_store/HRRR',hinp = '', scaling = 1, final_unit = '', margin = .3)
#
# /data/san_store/HRRR/pyhrrr.pyc in plot_hrrr_sgp(filename, parameter, directory, hinp, scaling, final_unit, margin, vmax, vmin)
#      29         [data,parameterlist,units] = read_hrrr(filename,[parameter])
#      30     else:
# ---> 31         [data,parameterlist,units] = read_hrrr(filename,[parameter],directory = directory,max=True)
#      32
#      33     if hinp !='':
#
# /data/san_store/HRRR/pyhrrr.pyc in read_hrrr(filename, parameters, directory, max)
#      71             mixdata = np.zeros((40,1059,1799))
#      72             for j in params:
# ---> 73                 grb = myfile.select(name = j)
#      74                 grb_cube = grb_to_grid(grb)
#      75
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/pygrib.so in pygrib.open.select (pygrib.c:5243)()
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/pygrib.so in pygrib.open.__next__ (pygrib.c:3296)()
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/pygrib.so in pygrib._create_gribmessage (pygrib.c:6606)()
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/pygrib.so in pygrib.setdates (pygrib.c:6988)()
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/pygrib.so in pygrib.gribmessage.__setattr__ (pygrib.c:8603)()
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/pygrib.so in pygrib.gribmessage.__setitem__ (pygrib.c:12585)()
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     390 einsum = multiarray.einsum
#     391
# --> 392 def asarray(a, dtype=None, order=None):
#     393     """
#     394     Convert the input to an array.
#
# KeyboardInterrupt:
