# %%
import pyhrrr
import datetime
# %matplotlib inline
pyhrrr.plot_skewt_compare(datetime.datetime(2014,4,1),
                          '/data/san_store/soundings/sgp/mckercherg1/159821',1,sound_num=1)
pyhrrr.plot_skewt_compare(datetime.datetime(2014,4,1),
                          '/data/san_store/soundings/sgp/mckercherg1/159821',1,sound_num=2)
pyhrrr.plot_skewt_compare(datetime.datetime(2014,4,1),
                          '/data/san_store/soundings/sgp/mckercherg1/159821',1,sound_num=3)
pyhrrr.plot_skewt_compare(datetime.datetime(2014,4,1),
                          '/data/san_store/soundings/sgp/mckercherg1/159821',1,sound_num=4)
# Out:
# Reading sgpsondewnpnC1.b1.20140401.053000.cdf
# No cloud
# Reading hrrr.3d.20140401t000024r001L459899.txt
# HRRR Model Sounding, Forecast:
#  2014-04-01 04:30:00 for 1 hour
# Reading sgpsondewnpnC1.b1.20140401.112900.cdf
# No cloud
# Reading hrrr.3d.20140401t000024r001L459899.txt
# HRRR Model Sounding, Forecast: 2014-04-01 10:29:00 for 1 hour
# Reading sgpsondewnpnC1.b1.20140401.173000.cdf
# Balloon 100% saturation:
#  868.11 hPa - 828.73 hPa
# Reading hrrr.3d.20140401t000024r001L459899.txt
# HRRR Model Sounding, Forecast: 2014-04-01 16:30:00 for 1 hour
# Reading sgpsondewnpnC1.b1.20140401.233000.cdf
# No cloud
# Reading hrrr.3d.20140401t000024r001L459899.txt
# HRRR Model Sounding, Forecast: 2014-04-01 22:30:00 for 1 hour
