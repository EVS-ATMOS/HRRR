# %%
radar_directory = '/home/mjohnson/python/radar_txt'
hrrr_directory = '/home/mjohnson/python/hrrr_txt'

# %%
import datetime
import pyhrrr
import json
import os
import matplotlib.dates
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
date = datetime.datetime(2014,6,7) #change for date

# %%
radar_string = pyhrrr.produce_radar_txt_string(date)
hrrr_string = pyhrrr.produce_hrrr_txt_string(date,filenum = 24,hour = 1,loc=[36.605, -97.485], indexes = None,
                                             modelhours = False)

# %%
wkdir = os.getcwd()
os.chdir(hrrr_directory)
hrrrf = open(hrrr_string,'r')
hrrr = json.load(hrrrf)
os.chdir(radar_directory)
radarf = open(radar_string,'r')
radar = json.load(radarf)

# %%
hrrr[0] = np.array(hrrr[0])

# %%
heights = radar[1]

# %%
hrrr[0].shape
# Out:
# (24, 14, 40)

# %%
#ind = hrrr[2].index() #change for parameter
hrrr_data = np.array(hrrr[0][:,-5,:])+np.array(hrrr[0][:,-4,:])+np.array(hrrr[0][:,-3,:])+np.array(hrrr[0][:,-2,:])+np.array(hrrr[0][:,-1,:])
hrrr_data = np.array(hrrr_data)
#hrrr_c = hrrr_data[:,ind]

# %%
radar = np.array(radar[0])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr_data,final_unit = 'Total mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(radar,final_unit = 'dBz',date = None,loc = None,ps = np.array(heights[2:40]), hour=1, scaling = 1,
                            figsize = [15,8],log=False,invert=False,ylabel='Height in m')

# %%
heights[2:40],pyhrrr.HRRR_PS[2:40]
# Out:
# ([315.0,
#   531.0870429475334,
#   761.7054132255649,
#   997.4290259542779,
#   1239.5404467396602,
#   1488.729109503926,
#   1745.4067466179556,
#   2008.443447266162,
#   2277.558837916097,
#   2553.3990797771025,
#   2836.544829299297,
#   3127.6094346041828,
#   3427.1278789043427,
#   3735.0,
#   4053.79157781897,
#   4384.112566945904,
#   4725.6039143700245,
#   5078.993701102021,
#   5444.131265632816,
#   5823.084702354754,
#   6216.645877189845,
#   6626.525019901093,
#   7053.799967447917,
#   7501.10009765625,
#   7973.856337549411,
#   8471.5,
#   8999.463088952003,
#   9562.46871256169,
#   10163.109486903795,
#   10808.774331408827,
#   11506.099609375,
#   12266.933307654253,
#   13106.812609831462,
#   14050.400390625,
#   15191.81241464624,
#   16577.0995647852,
#   18299.067057291668,
#   20791.457679134026],
#  array([975, 950, 925, 900, 875, 850, 825, 800, 775, 750, 725, 700, 675,
#         650, 625, 600, 575, 550, 525, 500, 475, 450, 425, 400, 375, 350,
#         325, 300, 275, 250, 225, 200, 175, 150, 125, 100,  75,  50]))

# %%
pyhrrr.HRRR_PS[2:40].tolist().index(500)
# Out:
# 19

# %%
heights[19]
# Out:
# 5078.993701102021

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-5,:],final_unit = 'Cloud mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-0a1377f2c650> in <module>()
#       1 pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-5,:],final_unit = 'Cloud mixing ratio kg/kg**-1',numdates = hrrr[1],date = None,
# ----> 2                             loc = None,ps = radar[1], hour=1, scaling = 1,figsize = [15,8])
#
# /home/mjohnson/python/radar_txt/pyhrrr.pyc in plot_hrrr_dayfromtxt(matrix, final_unit, numdates, date, loc, ps, hour, scaling, figsize)
#      56     ax.yaxis.set_major_formatter(ymajorFormatter)
#      57
# ---> 58     pc = plt.pcolormesh(times,ps,np.transpose(values))
#      59     ax.set_ylim([100,max(HRRR_PS)])
#      60     ax.set_xlim([0,24])
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in pcolormesh(*args, **kwargs)
#    3028         ax.hold(hold)
#    3029     try:
# -> 3030         ret = ax.pcolormesh(*args, **kwargs)
#    3031         draw_if_interactive()
#    3032     finally:
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in pcolormesh(self, *args, **kwargs)
#    4998         allmatch = (shading == 'gouraud')
#    4999
# -> 5000         X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
#    5001         Ny, Nx = X.shape
#    5002
#
# /home/jhelmus/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in _pcolorargs(funcname, *args, **kw)
#    4628                 raise TypeError('Dimensions of C %s are incompatible with'
#    4629                                 ' X (%d) and/or Y (%d); see help(%s)' % (
# -> 4630                                     C.shape, Nx, Ny, funcname))
#    4631             C = C[:Ny - 1, :Nx - 1]
#    4632         return X, Y, C
#
# TypeError: Dimensions of C (40, 24) are incompatible with X (25) and/or Y (38); see help(pcolormesh)

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-4,:],final_unit =  pyhrrr.HRRR_VARS[-4]+' kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-3,:],final_unit =  pyhrrr.HRRR_VARS[-3]+' kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-2,:],final_unit =  pyhrrr.HRRR_VARS[-2]+' kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,-1,:],final_unit =  pyhrrr.HRRR_VARS[-1]+' kg/kg**-1',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,6,:],final_unit =  pyhrrr.HRRR_VARS[6]+' m/s',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,7,:],final_unit =  pyhrrr.HRRR_VARS[7]+' m/s',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
pyhrrr.plot_hrrr_dayfromtxt(hrrr[0][:,5,:],final_unit =  pyhrrr.HRRR_VARS[5]+' m/s',numdates = hrrr[1],date = None,
                            loc = None,ps = pyhrrr.HRRR_PS, hour=1, scaling = 1,figsize = [15,8])

# %%
filename = pyhrrr.produce_hrrr_grib2strings([date+datetime.timedelta(hours=3)],[[1]])
filename = filename[0]

# %%
pyhrrr.plot_hrrr_sgp(filename,parameter='Total mixing ratio',directory = '/data/san_store/HRRR',hinp = '', scaling = 1, final_unit = '', margin = .3)
