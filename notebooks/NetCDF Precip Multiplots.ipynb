# %%
import pyhrrr
# %matplotlib inline

# %%
kazr = 'sgpkazrgeC1.a1.20140523.000001.cdf'
ceilometer = 'sgpvceil25kC1.b1.20140523.000000.cdf'
disdrometer = 'sgpdisdrometerC1.b1.20140523.000000.cdf'

# %%
pyhrrr.plot_kazr_2(kazr,ceilometer)

# %%
pyhrrr.plot_disdrometer(disdrometer)
# Out:
# --------------------------------------------------------------
# -----------------PRECIPITATION INFORMATION--------------------
# --------------------------------------------------------------
#
# Total Precipitation Duration: 2.21666666667 hours, 133.0 minutes, 7980.0 seconds
# Total Precipitation Amount: 23.3606 mm, 0.0919708913799 in
# Total Rain Rate Recording Duration: 6.91666666667 hours, 415.0 minutes, 24900.0 seconds
# Light Rain Rate Duration: 5.68333333333 hours, 341.0 minutes, 20460.0 seconds
# Medium Rain Rate Duration: 1.23333333333 hours, 74.0 minutes, 4440.0 seconds
# Heavy Rain Rate Duration: 0.0 hours, 0.0 minutes, 0.0 seconds
# Average Rain Rate: 0.973483 mm/hr, 0.0038326124083 in/hr
