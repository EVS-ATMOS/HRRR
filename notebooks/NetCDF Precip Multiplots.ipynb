# %%
import pyhrrr
# %matplotlib inline

# %%
kazr = '/data/san_store/radar/sgp/kazr/mckercherg1/160107/sgpkazrgeC1.a1.20140527.000002.cdf'
ceilometer = '/data/san_store/gmckercher/ceilometer/sgpvceil25kC1_marchtojune/sgpvceil25kC1.b1.20140527.000007.cdf'
disdrometer = '/data/san_store/gmckercher/disdrometer/mckercherg1/160313/sgpdisdrometerC1.b1.20140527.000000.cdf'

# %%
pyhrrr.plot_kazr_2(kazr,ceilometer)

# %%
pyhrrr.plot_disdrometer(disdrometer)
# Out:
# --------------------------------------------------------------
# -----------------PRECIPITATION INFORMATION--------------------
# --------------------------------------------------------------
#
# Total Precipitation Duration: 2.23333333333 hours, 134.0 minutes, 8040.0 seconds
# Total Precipitation Amount: 0.252 mm, 0.000992126183961 in
# Total Rain Rate Recording Duration: 8.06666666667 hours, 484.0 minutes, 29040.0 seconds
# Light Rain Rate Duration: 8.06666666667 hours, 484.0 minutes, 29040.0 seconds
# Medium Rain Rate Duration: 0.0 hours, 0.0 minutes, 0.0 seconds
# Heavy Rain Rate Duration:
#  0.0 hours, 0.0 minutes, 0.0 seconds
# Average Rain Rate: 0.0106263 mm/hr, 4.18360079652e-05 in/hr
